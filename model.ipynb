# %% [markdown]
# ## ML model

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
from sklearn.model_selection import train_test_split

# %% [markdown]
# ### EDA

# %%
df = pd.read_csv("creditcard.csv")

# %%
df.head()
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281 -0.327642
# 3  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321 -1.175575  0.647376
# 4 -0.270533  0.817739  ... -0.009431  0.798278 -0.137458  0.141267 -0.206010
#
# ...

# %%
df.shape
# Out:
# (284807, 31)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 284807 entries, 0 to 284806
# Data columns (total 31 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   Time    284807 non-null  float64
#  1   V1      284807 non-null  float64
#  2   V2      284807 non-null  float64
#  3   V3      284807 non-null  float64
#  4   V4      284807 non-null  float64
#  5   V5      284807 non-null  float64
#  6   V6      284807 non-null  float64
#  7   V7      284807 non-null  float64
#  8   V8      284807 non-null  float64
#  9   V9      284807 non-null  float64
#  10  V10     284807 non-null  float64
#  11  V11     284807 non-null  float64
#  12  V12     284807 non-null  float64
#  13  V13     284807 non-null  float64
#  14  V14     284807 non-null  float64
#  15  V15     284807 non-null  float64
#  16  V16     284807 non-null  float64
#  17  V17     284807 non-null  float64
#  18  V18     284807 non-null  float64
#  19  V19     284807 non-null  float64
# ...

# %%
df.isnull().sum()
# Out:
# Time      0
# V1        0
# V2        0
# V3        0
# V4        0
# V5        0
# V6        0
# V7        0
# V8        0
# V9        0
# V10       0
# V11       0
# V12       0
# V13       0
# V14       0
# V15       0
# V16       0
# V17       0
# V18       0
# V19       0
# V20       0
# V21       0
# V22       0
# V23       0
# V24       0
# V25       0
# V26       0
# V27       0
# V28       0
# Amount    0
# Class     0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 1081

# %%
df = df.drop_duplicates()
df.shape
# Out:
# (283726, 31)

# %%
df.describe()
# Out:
#                 Time             V1             V2             V3  \
# count  283726.000000  283726.000000  283726.000000  283726.000000
# mean    94811.077600       0.005917      -0.004135       0.001613
# std     47481.047891       1.948026       1.646703       1.508682
# min         0.000000     -56.407510     -72.715728     -48.325589
# 25%     54204.750000      -0.915951      -0.600321      -0.889682
# 50%     84692.500000       0.020384       0.063949       0.179963
# 75%    139298.000000       1.316068       0.800283       1.026960
# max    172792.000000       2.454930      22.057729       9.382558
#
#                   V4             V5             V6             V7  \
# count  283726.000000  283726.000000  283726.000000  283726.000000
# mean       -0.002966       0.001828      -0.001139       0.001801
# std         1.414184       1.377008       1.331931       1.227664
# min        -5.683171    -113.743307     -26.160506     -43.557242
# ...

# %%
df["Class"].value_counts()
# Out:
# Class
# 0    283253
# 1       473
# Name: count, dtype: int64

# %%
df.corr()
# Out:
#             Time        V1        V2        V3        V4        V5        V6  \
# Time    1.000000  0.117927 -0.010556 -0.422054 -0.105845  0.173223 -0.063279
# V1      0.117927  1.000000  0.006875 -0.008112  0.002257 -0.007036  0.000413
# V2     -0.010556  0.006875  1.000000  0.005278 -0.001495  0.005210 -0.000594
# V3     -0.422054 -0.008112  0.005278  1.000000  0.002829 -0.006879 -0.001511
# V4     -0.105845  0.002257 -0.001495  0.002829  1.000000  0.001744 -0.000880
# V5      0.173223 -0.007036  0.005210 -0.006879  0.001744  1.000000 -0.000938
# V6     -0.063279  0.000413 -0.000594 -0.001511 -0.000880 -0.000938  1.000000
# V7      0.085335 -0.009173  0.007425 -0.011721  0.004657 -0.008709  0.000436
# V8     -0.038203 -0.001168  0.002899 -0.001815  0.000890  0.001430  0.003036
# V9     -0.007861  0.001828 -0.000274 -0.003579  0.002154 -0.001213 -0.000734
# V10     0.031068  0.000815  0.000620 -0.009632  0.002753 -0.006050 -0.002180
# ...

# %%
sns.heatmap(df.corr(), fmt=".2f", cmap="coolwarm")
plt.show()

# %%
fraud = df[df['Class'] == 1]
legit = df[df['Class'] == 0]

# %%
fraud.describe()
# Out:
#                 Time          V1          V2          V3          V4  \
# count     473.000000  473.000000  473.000000  473.000000  473.000000
# mean    80450.513742   -4.498280    3.405965   -6.729599    4.472591
# std     48636.179973    6.593145    4.122500    6.909647    2.871523
# min       406.000000  -30.552380   -8.402154  -31.103685   -1.313275
# 25%     41203.000000   -5.603690    1.145381   -7.926507    2.288644
# 50%     73408.000000   -2.271755    2.617105   -4.875397    4.100098
# 75%    129095.000000   -0.361428    4.571743   -2.171454    6.290918
# max    170348.000000    2.132386   22.057729    2.250210   12.114672
#
#                V5          V6          V7          V8          V9  ...  \
# count  473.000000  473.000000  473.000000  473.000000  473.000000  ...
# mean    -2.957197   -1.432518   -5.175912    0.953255   -2.522124  ...
# std      5.278831    1.715347    6.858024    5.585950    2.465047  ...
# ...

# %%
legit.describe()
# Out:
#                 Time             V1             V2             V3  \
# count  283253.000000  283253.000000  283253.000000  283253.000000
# mean    94835.058093       0.013439      -0.009829       0.012853
# std     47475.550607       1.922179       1.633520       1.457593
# min         0.000000     -56.407510     -72.715728     -48.325589
# 25%     54233.000000      -0.913431      -0.601398      -0.883966
# 50%     84711.000000       0.022562       0.062561       0.182247
# 75%    139308.000000       1.316788       0.797012       1.028261
# max    172792.000000       2.454930      18.902453       9.382558
#
#                   V4             V5             V6             V7  \
# count  283253.000000  283253.000000  283253.000000  283253.000000
# mean       -0.010440       0.006769       0.001251       0.010447
# std         1.398575       1.355816       1.329914       1.177480
# min        -5.683171    -113.743307     -26.160506     -31.764946
# ...

# %%
df['Time'].plot()
# Out:
# <Axes: >

# %% [markdown]
# ### Process data

# %% [markdown]
# From the analysis above, we can see that the dataset is highly imbalanced. The number of legit transactions greatly outnumbers that of fraud transactions. Therefore, we may need to set the bias of our network's last layer.

# %% [markdown]
# Additionally, the Time variable doesn't provide much inside, while the Amount variable varies too much. Therefore, we'll drop the Time column and take the log of the Amount column.

# %%
df.head()
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281 -0.327642
# 3  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321 -1.175575  0.647376
# 4 -0.270533  0.817739  ... -0.009431  0.798278 -0.137458  0.141267 -0.206010
#
# ...

# %%
df.head()
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281 -0.327642
# 3  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321 -1.175575  0.647376
# 4 -0.270533  0.817739  ... -0.009431  0.798278 -0.137458  0.141267 -0.206010
#
# ...

# %%
df.columns
# Out:
# Index(['Time', 'V1', 'V2', 'V3', 'V4', 'V5', 'V6', 'V7', 'V8', 'V9', 'V10',
#        'V11', 'V12', 'V13', 'V14', 'V15', 'V16', 'V17', 'V18', 'V19', 'V20',
#        'V21', 'V22', 'V23', 'V24', 'V25', 'V26', 'V27', 'V28', 'Amount',
#        'Class'],
#       dtype='object')

# %%
df = df.drop(["Time"], axis=1)
df["Amount"] = np.log(df["Amount"]+0.001)

# %%
df.describe()
# Out:
#                   V1             V2             V3             V4  \
# count  283726.000000  283726.000000  283726.000000  283726.000000
# mean        0.005917      -0.004135       0.001613      -0.002966
# std         1.948026       1.646703       1.508682       1.414184
# min       -56.407510     -72.715728     -48.325589      -5.683171
# 25%        -0.915951      -0.600321      -0.889682      -0.850134
# 50%         0.020384       0.063949       0.179963      -0.022248
# 75%         1.316068       0.800283       1.026960       0.739647
# max         2.454930      22.057729       9.382558      16.875344
#
#                   V5             V6             V7             V8  \
# count  283726.000000  283726.000000  283726.000000  283726.000000
# mean        0.001828      -0.001139       0.001801      -0.000854
# std         1.377008       1.331931       1.227664       1.179054
# min      -113.743307     -26.160506     -43.557242     -73.216718
# ...

# %%
train, test = train_test_split(df, test_size=0.2)
train, val = train_test_split(train, test_size=0.2)

# %%
train_labels = train["Class"]
val_labels = val["Class"]
test_labels = test["Class"]

train_features = np.array(train.drop("Class", axis=1))
val_features = np.array(val.drop("Class", axis=1))
test_features = np.array(test.drop("Class", axis=1))

# %%
print(train_labels.mean())
print(val_labels.mean())
print(test_labels.mean())
# Out:
# 0.0016851704996034894
# 0.001674156313331571
# 0.00160363726077609

# %% [markdown]
# The probabilities of fraud transactions across all sets are pretty even, so we have a good split to start training.
